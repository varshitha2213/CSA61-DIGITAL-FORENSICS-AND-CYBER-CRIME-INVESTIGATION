# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitha2213/CSA61-DIGITAL-FORENSICS-AND-CYBER-CRIME-INVESTIGATION/blob/main/EXP12(UNIT2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

ioc_data=[
["WannaCry",".WNCRY","iuqerfsodp9ifjaposdfjhgosurijfaewrwergwea.com","Kill Switch"],
["LockBit",".lockbit","lockbit-support.com","TOR Payment"],
["Conti",".conti","contirecovery.com","Bitcoin"]
]

df=pd.DataFrame(ioc_data,
columns=["Family","Extension","Domain","Note"])

print(df)

print("\nYARA-like Rules\n")

for row in ioc_data:

    print(f"""
rule {row[0]}
{{
    strings:
        $ext = "{row[1]}"
        $dom = "{row[2]}"
    condition:
        any of them
}}
""")
# Out:
#      Family Extension                                         Domain  \
# 0  WannaCry    .WNCRY  iuqerfsodp9ifjaposdfjhgosurijfaewrwergwea.com
# 1   LockBit  .lockbit                            lockbit-support.com
# 2     Conti    .conti                              contirecovery.com
#
#           Note
# 0  Kill Switch
# 1  TOR Payment
# 2      Bitcoin
#
# YARA-like Rules
#
#
# rule WannaCry
# {
#     strings:
#         $ext = ".WNCRY"
#         $dom = "iuqerfsodp9ifjaposdfjhgosurijfaewrwergwea.com"
#     condition:
#         any of them
# }
#
#
# rule LockBit
# {
#     strings:
#         $ext = ".lockbit"
#         $dom = "lockbit-support.com"
#     condition:
#         any of them
# }
#
#
# rule Conti
# {
#     strings:
#         $ext = ".conti"
#         $dom = "contirecovery.com"
#     condition:
#         any of them
# }
