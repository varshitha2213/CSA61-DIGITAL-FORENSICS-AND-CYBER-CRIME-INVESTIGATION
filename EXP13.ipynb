# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitha2213/CSA61-DIGITAL-FORENSICS-AND-CYBER-CRIME-INVESTIGATION/blob/main/EXP13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime

case_id = "CASE-101"
investigator = "Varshitha"
device = "Laptop"
evidence = "sample.jpg"

findings = [
    "Image examined successfully.",
    "EXIF metadata extracted.",
    "No image tampering detected.",
    "Evidence integrity maintained."
]

print("="*50)
print("      DIGITAL FORENSIC REPORT")
print("="*50)

print("Case ID       :", case_id)
print("Investigator  :", investigator)
print("Date          :", datetime.now().strftime("%d-%m-%Y %H:%M:%S"))
print("Device        :", device)
print("Evidence File :", evidence)

print("\nInvestigation Findings")
print("-"*30)

for i, finding in enumerate(findings, 1):
    print(f"{i}. {finding}")

print("\nConclusion")
print("-"*30)
print("The evidence has been successfully analyzed.")
print("The forensic report has been generated.")
# Out:
# ...
#       DIGITAL FORENSIC REPORT
# ...
# Case ID       : CASE-101
# Investigator  : Varshitha
# Date          : 30-07-2026 05:25:14
# Device        : Laptop
# Evidence File : sample.jpg
#
# Investigation Findings
# ------------------------------
# 1. Image examined successfully.
# 2. EXIF metadata extracted.
# 3. No image tampering detected.
# 4. Evidence integrity maintained.
#
# Conclusion
# ------------------------------
# The evidence has been successfully analyzed.
# The forensic report has been generated.
